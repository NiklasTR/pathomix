# %%
import pandas as pd
import numpy as np

# %%
cosmic = pd.read_csv('../data/cosmic/CosmicGenomeScreensMutantExport.tsv', sep='\t')

# %% [markdown]
# I am interested in the frequency of genetic alterations for each gene and cancer type. I am only interested in missense and nonsense mutations that are changing the protein structure.

# %%
cosmic.head()
# Out:
#                Gene name   Accession Number  Gene CDS length  HGNC ID  \
# 0  CAPSL_ENST00000397366  ENST00000397366.5              969  28375.0
# 1                   RHAG  ENST00000371175.9             1957  10006.0
# 2                   RHAG  ENST00000371175.9             1957  10006.0
# 3                   RHAG  ENST00000371175.9             1957  10006.0
# 4  PORCN_ENST00000359882  ENST00000359882.8             1877  17652.0
#
#       Sample name  ID_sample  ID_tumour     Primary site Site subtype 1  \
# 0            HX5T    1473092    1396791            liver             NS
# 1  PCSI_0024_Pa_X    2121266    1995502         pancreas             NS
# 2        S00829_1    2480818    2343563             lung             NS
# 3       CSCC-27-T    2292469    2158533             skin      head_neck
# 4            T213    2658379    2518538  large_intestine             NS
#
#   Site subtype 2  ... Mutation strand SNP FATHMM prediction FATHMM score  \
# ...
